# %%
import sys ; sys.path.append("..")
import os  
import retriever_eval as retriever_eval
import matplotlib.pyplot as plt
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
ks = [1,3,5,10,20]
tables=['document_semantic_split', 'document_recursive_split_rst_separator_1000_50', 'document_recursive_split_default_300_50']
conn = retriever_eval.getConnection()

plt.figure(figsize=(10, 6))

for table in tables:
    result = []
    for k in ks:
        result.append(retriever_eval.calculate_average_hit_rate(conn, table, k))
    plt.plot(ks, result, marker='o', label=table)

plt.xlabel('k')
plt.ylabel('Average Hit Rate')
plt.title('Average Hit Rate for different tables')
plt.legend()
plt.show()

# %%
conn = retriever_eval.getConnection()
questions = retriever_eval.get_random_questions(conn, "document_semantic_split")

with open('questions.txt', 'w') as f:
    for question in questions:
        f.write(question + '\n')
